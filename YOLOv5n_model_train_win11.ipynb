# %%
import configparser 

config = configparser.ConfigParser() 
config.read("config.ini")
# Out:
# ['config.ini']

# %%
dataset_location = f'"C:\\Users\\Fomichev Nikita\\Desktop\\Study\\tadimo\\coursework\\dataset\\COCO2020_15.yolov8\\datav5.yaml"'

# %%
# %env CLEARML_WEB_HOST=https://app.clear.ml
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY={config["API_KEY"]["clearml_api_access_key"]}
# %env CLEARML_API_SECRET_KEY={config["API_KEY"]["clearml_api_secret_key"]}
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=7SBFEWHQUYXYVJUS8X21
# env: CLEARML_API_SECRET_KEY=7WzZ9a44wbtKvXZ2vdZyRGO2fJzhuJ3NPilLCWlgWa39psRSnP

# %%
from clearml import Task

task = Task.init(project_name="courseWork", task_name="final_train_yolov5_batch_16_epochs_100")
# Out:
# ClearML Task: created new task id=597f8e38b4e34c80b21aa8ac2e080362
# 2023-05-10 16:17:04,870 - clearml.Task - INFO - Storing jupyter notebook directly as code
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.util has been moved to tensorflow.python.checkpoint.checkpoint. The old module will be deleted in version 2.11.
# ClearML results page: https://app.clear.ml/projects/a78625dd95994b7fab12223aa34920c7/experiments/597f8e38b4e34c80b21aa8ac2e080362/output/log

# %%
# !nvidia-smi
# Out:
# Fri May 12 08:00:17 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 531.61                 Driver Version: 531.61       CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                      TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060       WDDM | 00000000:01:00.0  On |                  N/A |
# | 43%   37C    P5               13W / 190W|    548MiB / 12288MiB |     14%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\Fomichev Nikita\Desktop\Study\tadimo\coursework

# %%
# %cd {HOME}
# Out:
# c:\Users\Fomichev Nikita\Desktop\Study\tadimo\coursework

# %%
# %cd yolov5
# Out:
# c:\Users\Fomichev Nikita\Desktop\Study\tadimo\coursework\yolov5

# %%
import torch
import utils

display = utils.notebook_init()
# Out:
# YOLOv5  2023-5-10 Python-3.10.10 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# Setup complete  (12 CPUs, 31.9 GB RAM, 721.0/930.2 GB disk)

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data {dataset_location} --weights yolov5n.pt
# Out:
# requirements: C:\Users\Fomichev Nikita\Desktop\Study\tadimo\coursework\requirements.txt not found, check failed.
# 2023-05-11 08:58:21,245 - clearml.storage - INFO - Starting upload: runs\train\exp\weights\best.pt => https://files.clear.ml/courseWork/final_train_yolov5_batch_16_epochs_100.597f8e38b4e34c80b21aa8ac2e080362/models/best.pt
# 2023-05-11 08:58:28,779 - clearml.Task - INFO - Completed model upload to https://files.clear.ml/courseWork/final_train_yolov5_batch_16_epochs_100.597f8e38b4e34c80b21aa8ac2e080362/models/best.pt
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.4 --source ../dataset/COCO2020_15.yolov8/test/images
# Out:
# requirements: C:\Users\Fomichev Nikita\Desktop\Study\tadimo\coursework\requirements.txt not found, check failed.
# detect: weights=['runs/train/exp/weights/best.pt'], source=../dataset/COCO2020_15.yolov8/test/images, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Fomichev': No such file or directory
# YOLOv5  2023-5-10 Python-3.10.10 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1779460 parameters, 0 gradients, 4.2 GFLOPs
# ...

# %%
# !python val.py --weights runs/train/exp/weights/best.pt --data {dataset_location} --img 640
# Out:
# requirements: C:\Users\Fomichev Nikita\Desktop\Study\tadimo\coursework\requirements.txt not found, check failed.
# val: data=C:\Users\Fomichev Nikita\Desktop\Study\tadimo\coursework\dataset\COCO2020_15.yolov8\datav5.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to 'C:\Users\Fomichev': Invalid argument
# YOLOv5  2023-5-10 Python-3.10.10 torch-2.0.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1779460 parameters, 0 gradients, 4.2 GFLOPs
#
# val: Scanning C:\Users\Fomichev Nikita\Desktop\Study\tadimo\coursework\dataset\COCO2020_15.yolov8\valid\labels...:   0%|          | 0/8784 [00:00<?, ?it/s]
# ...

# %%
# from utils.plots import plot_results

# plot_results('runs/train/exp/results.csv')
